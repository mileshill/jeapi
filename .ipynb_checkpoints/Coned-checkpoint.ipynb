# %%
# %matplotlib inline

# generic
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# custom
from icap.database.icapdatabase import ICapDatabase
from icap.results.results import Results

# %%
fp = 'icap/database/icapdatabase.json'
conn = ICapDatabase(fp).connect()

if conn.__class__.__name__ != 'Connection':
    raise Exception('No Connection')

# %% [markdown]
# ## Temp Variant Testing

# %%
temp_station_query = """select
                RTrim(StationCode) as StationCode,
                ObservedDate, --Hour,
                Temperature, WetBulbTemperature
            from CONED_NYWeatherData
            order by
                ObservedDate"""

ts = pd.read_sql(temp_station_query, conn)

# %%
"""
Hourly Average:
    WetBulbTemperature = WBT; Temperature = T;
    
    for hour in ObservedDate:
        hourly_avg[i] = 0.25 * (KNYC_WBT + KNYC_T + KLGA_WBT + KLGA_T)

"""
hourly_avg = pd.pivot_table(ts, index='ObservedDate', 
               columns='StationCode', 
               values=['Temperature', 'WetBulbTemperature'],
                    ).mean(1)

# %%
"""
Rolling Average:
    1. Group hourly average into days
    2. Rolling mean over 3 hour window
    3. Take maximum average per day
"""
daily_max_avg = hourly_avg.groupby(pd.TimeGrouper('D')
                  ).rolling(window=3).mean().max(level=0)

# %%
"""
Rolling Weighted Sum
    weights = [0.1, 0.2, 0.7]
    day[i-2], day[i-1], day[i] = weights 

"""
# helper function to compute weighted sum
def f(w):
    def g(x):
        return (w * x).sum()
    return g

# Weights
wts = np.array([.1, .2, .7])

# %%
# CONVERSIONS
# convert hour into timedelta
# increment `ObservedDate` by correspoding Timedelta
# drop the `Hour` columns
ts['Hour'] = ts['Hour'].apply(lambda x: pd.Timedelta(hours=x))
ts['ObservedDate'] = ts['ObservedDate'] + ts['Hour']
td = ts.drop('Hour', axis=1)

# %%
# update index
#td.set_index('ObservedDate', inplace=True)
ts.set_index('ObservedDate', inplace=True)
ts.drop('Hour', axis=1, inplace=True)

# %%
ts.head()
# Out:
#                     StationCode  Temperature  WetBulbTemperature
# ObservedDate
# 2014-04-30 20:00:00        KNYC           48                  46
# 2014-04-30 20:00:00        KLGA           46                  45
# 2014-04-30 21:00:00        KLGA           48                  47
# 2014-04-30 21:00:00        KNYC           48                  47
# 2014-04-30 22:00:00        KNYC           48                  47

# %%
# AGGREGATION
# Station_i : sum = temperature + wetbulbtemperature

#td['RowSum'] = td.sum(axis=1)
ts['RowSum'] = ts.sum(axis=1)

# %%
knyc = td[td['StationCode'] == 'KNYC']
klga = td[td['StationCode'] == 'KLGA']

# %%
knyc.head()
# Out:
#                     StationCode  Temperature  WetBulbTemperature  RowSum
# ObservedDate
# 2014-05-01 16:00:00        KNYC           48                  46      94
# 2014-05-01 18:00:00        KNYC           48                  47      95
# 2014-05-01 20:00:00        KNYC           48                  47      95
# 2014-05-01 22:00:00        KNYC           50                  48      98
# 2014-05-01 00:00:00        KNYC           50                  48      98

# %%
klga.head()
# Out:
#                     StationCode  Temperature  WetBulbTemperature  RowSum
# ObservedDate
# 2014-05-01 16:00:00        KLGA           46                  45      91
# 2014-05-01 18:00:00        KLGA           48                  47      95
# 2014-05-01 20:00:00        KLGA           46                  45      91
# 2014-05-01 22:00:00        KLGA           48                  46      94
# 2014-05-01 00:00:00        KLGA           48                  47      95

# %%
ts.drop(['Temperature', 'WetBulbTemperature'], axis=1
       ).pivot(columns='StationCode', values='RowSum')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-437c769234e1> in <module>()
#       1 ts.drop(['Temperature', 'WetBulbTemperature'], axis=1
# ----> 2        ).pivot(columns='StationCode', values='RowSum')
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    3944         """
#    3945         from pandas.core.reshape import pivot
# -> 3946         return pivot(self, index=index, columns=columns, values=values)
#    3947
#    3948     def stack(self, level=-1, dropna=True):
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in pivot(self, index, columns, values)
#     334         indexed = Series(self[values].values,
#     335                          index=MultiIndex.from_arrays([index, self[columns]]))
# --> 336         return indexed.unstack(columns)
#     337
#     338
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2086         """
#    2087         from pandas.core.reshape import unstack
# -> 2088         return unstack(self, level, fill_value)
#    2089
#    2090     # ----------------------------------------------------------------------
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in unstack(obj, level, fill_value)
#     409     else:
#     410         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 411                                fill_value=fill_value)
#     412         return unstacker.get_result()
#     413
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in __init__(self, values, index, level, value_columns, fill_value)
#     101
#     102         self._make_sorted_values_labels()
# --> 103         self._make_selectors()
#     104
#     105     def _make_sorted_values_labels(self):
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in _make_selectors(self)
#     139
#     140         if mask.sum() < len(self.index):
# --> 141             raise ValueError('Index contains duplicate entries, '
#     142                              'cannot reshape')
#     143
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# drop columns aggregated in `RowSum`
# pivot stations into columns
# avg: (Station_i:RowSum) + (Station_j:RowSum) * (1/4)
hr_avg = td.drop(['Temperature', 'WetBulbTemperature'], axis=1
                 ).pivot(columns='StationCode', values='RowSum'
                         ).apply(lambda row: row.sum() * .25, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7790387a84ac> in <module>()
#       3 # avg: (Station_i:RowSum) + (Station_j:RowSum) * (1/4)
#       4 hr_avg = td.drop(['Temperature', 'WetBulbTemperature'], axis=1
# ----> 5                  ).pivot(columns='StationCode', values='RowSum'
#       6                          ).apply(lambda row: row.sum() * .25, axis=1)
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    3944         """
#    3945         from pandas.core.reshape import pivot
# -> 3946         return pivot(self, index=index, columns=columns, values=values)
#    3947
#    3948     def stack(self, level=-1, dropna=True):
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in pivot(self, index, columns, values)
#     334         indexed = Series(self[values].values,
#     335                          index=MultiIndex.from_arrays([index, self[columns]]))
# --> 336         return indexed.unstack(columns)
#     337
#     338
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    2086         """
#    2087         from pandas.core.reshape import unstack
# -> 2088         return unstack(self, level, fill_value)
#    2089
#    2090     # ----------------------------------------------------------------------
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in unstack(obj, level, fill_value)
#     409     else:
#     410         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 411                                fill_value=fill_value)
#     412         return unstacker.get_result()
#     413
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in __init__(self, values, index, level, value_columns, fill_value)
#     101
#     102         self._make_sorted_values_labels()
# --> 103         self._make_selectors()
#     104
#     105     def _make_sorted_values_labels(self):
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/reshape.py in _make_selectors(self)
#     139
#     140         if mask.sum() < len(self.index):
# --> 141             raise ValueError('Index contains duplicate entries, '
#     142                              'cannot reshape')
#     143
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# --

# %%
from icap.coned.coned import CONEDRecipe
c = CONEDRecipe(conn=conn, results=Results).run_all()

# %%
c.write_comparison_to_csv()
c.analyze_comparison(write_to_excel=True)
# Out:
#                                        ICap  CapacityTagValue
# MeterType Year RateClass Strata Valid
# CON       2015 2         2      0         1                 1
#           2016 2         2      0         1                 1
#                                 1         1                 1
#           2017 2         2      NULL      4                 0
#                8         8      NULL      2                 0
#                9         9      NULL      6                 0
# DMD       2015 1         1      0      2449              2449
#                                 1        96                96
#                                 NULL      1                11
#                116       116    0         1                 1
#                12        12     0         1                 1
#                2         2      0      1305              1305
#                                 1        24                24
#                                 NULL      1                27
#                21        21     0         4                 4
#                29        29     0         3                 3
#                37        37     0         1                 1
#                39        39     0         3                 3
#                40        40     0         3                 3
#                                 1         1                 1
#                41        41     0         3                 3
#                412       412    0         1                 1
#                51        51     0       107               107
#                                 1         2                 2
#                                 NULL      0                 1
#                58        58     0         1                 1
#                7         7      0        17                17
#                8         8      0        28                28
#                                 NULL      0                 1
#                9         9      0      1439              1439
# ...                                     ...               ...
#           2017 901       901    NULL    275                 0
#                921       921    NULL      1                 0
# INT       2015 12        12     0         2                 2
#                39        39     0         3                 3
#                51        51     0         1                 1
#                8         8      0         2                 2
#                9         9      0        27                27
#           2016 12        12     1         2                 2
#                39        39     0         2                 2
#                8         8      1         1                 1
#                9         9      0         1                 1
#                                 1        11                11
# VTOU      2015 1         1      NULL      0                 4
#                116       116    NULL      0                17
#                12        12     1         1                 1
#                39        39     1         3                 3
#                9         9      0        11                11
#                                 1        12                12
#                                 NULL      1                 0
#           2016 1         1      NULL      0                12
#                116       116    NULL      0                33
#                12        12     1         1                 1
#                39        39     1         2                 2
#                8         8      0         1                 1
#                9         9      0        16                16
#                                 1        10                10
#           2017 1         1      NULL      0                 0
#                116       116    NULL      0                 0
#                8         8      NULL      1                 0
#                9         9      NULL     17                 0
#
# [116 rows x 2 columns]

# %% [markdown]
# ## CONED Interval

# %%
# %%time
from icap.coned.coned import CONEDInterval
c = CONEDInterval(conn)
# Out:
# CPU times: user 1.68 s, sys: 44 ms, total: 1.72 s
# Wall time: 18.8 s

# %%
c.hourly.head().columns
# Out:
# Index(['RateClass', 'Service Classification', 'ZoneCode', 'Stratum', 'TOD',
#        'StartDate', 'EndDate', 'BilledUsage', 'BilledDemand', 'CPHourUsage',
#        'VarTest', 'MCD', 'NormUsage', 'MeterLogic', 'MeterRegex', 'Usage'],
#       dtype='object')

# %%
from icap.results.results import Results
r = Results(conn,c.compute_icap())

# %%
r.analyze_comparison()
# Out:
#                                        ICap  CapacityTagValue
# MeterType Year RateClass Strata Valid
# INT       2015 12        12     0         2                 2
#                39        39     0         3                 3
#                51        51     0         1                 1
#                8         8      0         2                 2
#                9         9      0        27                27
#           2016 12        12     1         2                 2
#                39        39     0         2                 2
#                8         8      1         1                 1
#                9         9      0         1                 1
#                                 1        11                11
# VTOU      2015 12        12     1         1                 1
#                39        39     1         3                 3
#                9         9      0         1                 1
#                                 1        12                12
#           2016 12        12     1         1                 1
#                39        39     1         2                 2
#                9         9      0         2                 2
#                                 1        10                10

# %%
hourly_cp = c.get_hourly_cp()

# %%
??c.meter_logic

# %%
hourly_rec = c.get_hourly()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     388                 result = np.empty(len(values), dtype=object)
# --> 389                 result[:] = values
#     390             except ValueError:
#
# ValueError: could not broadcast input array from shape (0,14) into shape (0)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2463             try:
# -> 2464                 value = Series(value)
#    2465             except:
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     240                 data = _sanitize_array(data, index, dtype, copy,
# --> 241                                        raise_cast_failure=True)
#     242
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2949         else:
# -> 2950             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    2951
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     391                 # we have a list-of-list
# --> 392                 result[:] = [tuple(x) for x in values]
#     393
#
# ValueError: cannot copy sequence with size 14 to array axis with dimension 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ece94db84845> in <module>()
# ----> 1 hourly_rec = c.get_hourly()
#
# /home/miles/Projects/BusinessLab/JustEnergy/icap/coned/coned.py in get_hourly(self)
#     340
#     341         # determine meter type
# --> 342         df['MeterLogic'] = df.apply(self.meter_logic, axis=1)
#     343         df['MeterRegex'] = df['MeterLogic'].apply(tod_regex)
#     344
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2417         else:
#    2418             # set column
# -> 2419             self._set_item(key, value)
#    2420
#    2421     def _setitem_slice(self, key, value):
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2482         """
#    2483
# -> 2484         self._ensure_valid_index(value)
#    2485         value = self._sanitize_column(key, value)
#    2486         NDFrame._set_item(self, key, value)
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2464                 value = Series(value)
#    2465             except:
# -> 2466                 raise ValueError('Cannot set a frame with no defined index '
#    2467                                  'and a value that cannot be converted to a '
#    2468                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
hourly_query = """
    select
        h.PremiseId,
        p.RateClass, ce.[Service Classification],
        ce.[Zone Code] as ZoneCode,
        ce.[Stratum Variable] as Stratum,
        ce.[Time of Day Code] as TOD,
        Year(m.EndDate) as Year,
        DateAdd(day, 0,  m.StartDate) as StartDate,
        m.EndDate,
        m.Usage as BilledUsage,
        m.Demand as BilledDemand,
        Round(Sum(h.Usage), 0) as CPHourUsage,
        'INT' as MeterType,
        iif(Abs((m.Usage-Sum(h.Usage))/m.Usage)<=0.04, 1, 0) as VarTest
    from [HourlyUsage]  h
    inner join [MonthlyUsage]  m
        on m.PremiseId = h.PremiseID
        and m.UtilityID = h.UtilityId
    inner join CoincidentPeak as cp
        on cp.UtilityId = h.UtilityId
        and Year(cp.CPDate) = Year(m.EndDate)
        and (cp.CPDate between m.StartDate and m.EndDate)
        and (h.UsageDate between m.StartDate and m.EndDate)
    inner join Premise as p
        on p.PremiseId = h.PremiseId
    inner join ConED as ce
        on CAST(ce.[Account Number] as varchar) = h.PremiseId
    where
        h.UtilityId = 'CONED'
        and h.HourEnding between 1 and 24
    group by
        h.PremiseId, MeterType,
        p.RateClass, ce.[Service Classification],
        ce.[Zone Code], ce.[Stratum Variable], ce.[Time of Day Code],
        Year(m.EndDate),
        m.StartDate, m.EndDate,
        m.Usage,
        m.Demand
    having
        Count(h.Usage) = (DateDiff(hour, m.StartDate, m.EndDate) + 24)
        """
# obtain data; set defaults; converions
df = pd.read_sql(hourly_query,conn)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [PremiseId, RateClass, Service Classification, ZoneCode, Stratum, TOD, Year, StartDate, EndDate, BilledUsage, BilledDemand, CPHourUsage, MeterType, VarTest]
# Index: []

# %%
df['MCD'] = np.NaN
df['NormUsage'] = np.NaN
df['TOD'] = df['TOD'].apply(lambda x: np.int(x))

# %%
# create multi-index; sort
df.set_index(['PremiseId', 'Year'], inplace=True)
df.sort_index(inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [RateClass, Service Classification, ZoneCode, Stratum, TOD, StartDate, EndDate, BilledUsage, BilledDemand, CPHourUsage, MeterType, VarTest, MCD, NormUsage]
# Index: []

# %%
# determine meter type
df['MeterLogic'] = df.apply(self.meter_logic, axis=1)
df['MeterRegex'] = df['MeterLogic'].apply(tod_regex)

# %%
r = Results(conn, c.compute_icap())

# %%
r.analyze_comparison()

# %% [markdown]
# ### Interval Varinace <= 4%

# %%
# select MCD; Usage[CP_date, CP_hour]
tmp = pd.merge(c.varTrue.reset_index(), c.hourly_cp, 
        how='left',
        on=['PremiseId', 'Year'])

# %%
tmp2 = pd.merge(tmp, c.util,
        how='left',
        left_on=['Year', 'ZoneCode'],
        right_on=['Year', 'Zone'])

# %%
match_mask = tmp2['MeterLogic'] == tmp2['MeterType_y']
all_mask = tmp2['MeterType_y'] == 'ALL'
mask = (match_mask == 1) | (all_mask == 1)

tmp2['Factor'] = tmp2['Factor'].apply(lambda x: x + 1.0)


tmp2['MCD'] = tmp2['Usage']
tmp2.ix[mask].groupby(['PremiseId', 'Year', 'RateClass', 'MeterLogic']).apply(coned_icap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c7f560ba05ad> in <module>()
#       7
#       8 tmp2['MCD'] = tmp2['Usage']
# ----> 9 tmp2.ix[mask].groupby(['PremiseId', 'Year', 'RateClass', 'MeterLogic']).apply(coned_icap)
#
# NameError: name 'coned_icap' is not defined

# %%
tmp2['Factor'] = tmp2['Factor'].apply(lambda x: x + 1.0)

# %%
c.__dict__.keys()
# Out:
# dict_keys(['hourly', 'util', 'temp_var', 'varTrue', 'cp', 'conn', 'tod_map', 'varFalse', 'params', 'hourly_cp', 'rc_map', 'lst'])

# %%
def coned_icap(g):
    mcd = g['Usage'].values
    stf = g[g['ParameterId'] == 'SubzoneTrueupFactor']['Factor'].values
    ftf = g[g['ParameterId'] == 'ForecastTrueupFactor']['Factor'].values
    try:
        icap = mcd[0] * stf[0] * ftf[0]
    except IndexError:
        icap = np.nan
    return icap

# %%
tmp2.groupby(['PremiseId', 'Year', 'RateClass']).apply(coned_icap)
# Out:
# PremiseId        Year  RateClass
# 295118610000006  2014  9            1940.745655
#                  2015  9            1926.716482
# 299011610500024  2014  9              98.770568
# 393011440000000  2014  9             550.117929
#                  2015  9             558.978161
# 393021200700004  2014  51            656.248290
# 393031443500004  2014  9             217.686875
# 393161340500003  2014  9             801.577554
# 393181404000005  2014  9             517.585506
#                  2015  9             628.092598
# 393181404500004  2014  9            2206.498213
#                  2015  9            2111.021646
# 463129207600005  2014  9             617.049388
#                  2015  9             672.956355
# 494011340000009  2014  9             761.312015
# 494013609000001  2014  9             583.716988
# 494013704000005  2014  9             711.580074
# 494022308200010  2014  9            1151.567753
# 494022308210001  2014  9             604.783065
# 494032427400037  2014  9            2655.125650
# 494051039100017  2014  9             710.646767
# 494051075400008  2014  9             596.249970
#                  2015  9             635.367802
# 494051117000006  2014  39           1235.165413
#                  2015  39           1258.610263
# 494091014000006  2014  39           1743.657840
#                  2015  39           1860.027114
# 494101110400008  2014  39           3329.240107
# 494112411000009  2014  9             850.109528
#                  2015  9             905.762877
#                                        ...
# 495108081000005  2015  9             716.607578
# 495120204100000  2014  9             391.989023
#                  2015  9             436.512230
# 590002460080023  2014  9             457.467748
#                  2015  9             403.586067
# 590003513000000  2014  9             508.839682
#                  2015  9             518.184580
# 590004510090028  2014  9             557.365150
# 590010657010000  2014  9            1252.173943
# 590021510320031  2014  9             255.639755
# 590021510330022  2014  9             415.177396
# 695101410000000  2014  9            2385.533200
#                  2015  9            2187.411286
# 695102020000018  2015  9            1720.585707
# 695102023800034  2014  9            3552.967175
#                  2015  9            3968.623692
# 696041716300002  2014  8             431.454585
# 696111207100029  2014  9             175.461753
# 696131505101008  2014  12            761.312015
#                  2015  12            807.547626
# 696141800800006  2014  8             950.373387
#                  2015  8             968.814644
# 696171060400007  2014  12            486.386380
#                  2015  12            552.915491
# 696191191400007  2014  12            275.458953
#                  2015  12            277.670280
# 795116007000030  2014  9             737.046028
#                  2015  9             774.809208
# 795116007200010  2014  9            1320.496356
#                  2015  9            1325.299632
# dtype: float64

# %% [markdown]
# ## CONED Monthly

# %%
# %%time
from icap.coned.coned import CONEDMonthly
c = CONEDMonthly(conn=conn)

# %%
# %%time
c.compute_mcd()
# Out:
# CPU times: user 7min 56s, sys: 716 ms, total: 7min 57s
# Wall time: 7min 57s

# %%
icap = c.compute_icap()

# %%
icap.head()
# Out:
#                      RunDate  ISO Utility        PremiseId  Year RateClass  \
# 0 2017-01-11 13:47:25.689545  PJM   CONED  211304006900006  2017         9
# 1 2017-01-11 13:47:25.689545  PJM   CONED  211306319000002  2015         9
# 2 2017-01-11 13:47:25.689545  PJM   CONED  211306319000002  2016         9
# 3 2017-01-11 13:47:25.689545  PJM   CONED  211306319000002  2017         9
# 4 2017-01-11 13:47:25.689545  PJM   CONED  211306350500001  2015         9
#
#   Strata MeterType       ICap
# 0      9       DMD  86.849577
# 1      9       DMD  67.566771
# 2      9       DMD  82.011537
# 3      9       DMD  76.797542
# 4      9       DMD   3.117239

# %%
r = Results(conn, icap)

# %%
r.analyze_comparison(write_to_excel=True)

# %%
results = r.compare_.copy()

# %%
null_idx = results[pd.isnull(results['HistVar'])].index
valid_idx = results[results['HistVar'] <= 2.0].index
invalid_idx = results[results['HistVar'] > 2.0].index

# %%
# assign values to outcomes on their index
results['Valid'] = ''
results.set_value(null_idx, 'Valid', 'NULL')
results.set_value(invalid_idx, 'Valid', 0)
results.set_value(valid_idx, 'Valid', 1)
# Out:
#                          RunDate  ISO Utility        PremiseId  Year  \
# 0     2017-01-11 12:54:48.692538  PJM   CONED  211304006900006  2017
# 1     2017-01-11 12:54:48.692538  PJM   CONED  211306319000002  2015
# 2     2017-01-11 12:54:48.692538  PJM   CONED  211306319000002  2016
# 3     2017-01-11 12:54:48.692538  PJM   CONED  211306319000002  2017
# 4     2017-01-11 12:54:48.692538  PJM   CONED  211306350500001  2015
# 5     2017-01-11 12:54:48.692538  PJM   CONED  211306350500001  2016
# 6     2017-01-11 12:54:48.692538  PJM   CONED  211306350500001  2017
# 7     2017-01-11 12:54:48.692538  PJM   CONED  211306373500053  2015
# 8     2017-01-11 12:54:48.692538  PJM   CONED  211306373500053  2016
# 9     2017-01-11 12:54:48.692538  PJM   CONED  211306373500053  2017
# 10    2017-01-11 12:54:48.692538  PJM   CONED  211306448500039  2015
# 11    2017-01-11 12:54:48.692538  PJM   CONED  211306448500039  2016
# 12    2017-01-11 12:54:48.692538  PJM   CONED  211306448500039  2017
# 13    2017-01-11 12:54:48.692538  PJM   CONED  211312003500059  2016
# 14    2017-01-11 12:54:48.692538  PJM   CONED  211312081500062  2017
# 15    2017-01-11 12:54:48.692538  PJM   CONED  211312447000005  2016
# 16    2017-01-11 12:54:48.692538  PJM   CONED  211312447000005  2017
# 17    2017-01-11 12:54:48.692538  PJM   CONED  211324063500002  2017
# 18    2017-01-11 12:54:48.692538  PJM   CONED  211324065000027  2017
# 19    2017-01-11 12:54:48.692538  PJM   CONED  211324066000059  2017
# 20    2017-01-11 12:54:48.692538  PJM   CONED  211326006000024  2015
# 21    2017-01-11 12:54:48.692538  PJM   CONED  211326006000024  2016
# 22    2017-01-11 12:54:48.692538  PJM   CONED  211326006000024  2017
# 23    2017-01-11 12:54:48.692538  PJM   CONED  211326135000010  2015
# 24    2017-01-11 12:54:48.692538  PJM   CONED  211326135000010  2016
# 25    2017-01-11 12:54:48.692538  PJM   CONED  211326135000010  2017
# 26    2017-01-11 12:54:48.692538  PJM   CONED  211326182500045  2015
# 27    2017-01-11 12:54:48.692538  PJM   CONED  211326182500045  2016
# 28    2017-01-11 12:54:48.692538  PJM   CONED  211326182500045  2017
# 29    2017-01-11 12:54:48.692538  PJM   CONED  211328014000038  2015
# ...                          ...  ...     ...              ...   ...
# 20435 2017-01-11 12:54:48.692538  PJM   CONED  702165043090010  2017
# 20436 2017-01-11 12:54:48.692538  PJM   CONED  702165043095035  2015
# 20437 2017-01-11 12:54:48.692538  PJM   CONED  702165043095035  2016
# 20438 2017-01-11 12:54:48.692538  PJM   CONED  702165043095035  2017
# 20439 2017-01-11 12:54:48.692538  PJM   CONED  702165043100058  2015
# 20440 2017-01-11 12:54:48.692538  PJM   CONED  702165043100058  2016
# 20441 2017-01-11 12:54:48.692538  PJM   CONED  702165043100058  2017
# 20442 2017-01-11 12:54:48.692538  PJM   CONED  702165043365065  2015
# 20443 2017-01-11 12:54:48.692538  PJM   CONED  702165043365065  2016
# 20444 2017-01-11 12:54:48.692538  PJM   CONED  702165043365065  2017
# 20445 2017-01-11 12:54:48.692538  PJM   CONED  702165043500026  2015
# 20446 2017-01-11 12:54:48.692538  PJM   CONED  702165043500026  2016
# 20447 2017-01-11 12:54:48.692538  PJM   CONED  702165043500026  2017
# 20448 2017-01-11 12:54:48.692538  PJM   CONED  702165140800030  2015
# 20449 2017-01-11 12:54:48.692538  PJM   CONED  702165140800030  2016
# 20450 2017-01-11 12:54:48.692538  PJM   CONED  702165140800030  2017
# 20451 2017-01-11 12:54:48.692538  PJM   CONED  702165140810039  2015
# 20452 2017-01-11 12:54:48.692538  PJM   CONED  702165140810039  2016
# 20453 2017-01-11 12:54:48.692538  PJM   CONED  702165140810039  2017
# 20454 2017-01-11 12:54:48.692538  PJM   CONED  795101001000004  2015
# 20455 2017-01-11 12:54:48.692538  PJM   CONED  795101001000004  2016
# 20456 2017-01-11 12:54:48.692538  PJM   CONED  795101001000004  2017
# 20457 2017-01-11 12:54:48.692538  PJM   CONED  795115042000005  2015
# 20458 2017-01-11 12:54:48.692538  PJM   CONED  795115042000005  2016
# 20459 2017-01-11 12:54:48.692538  PJM   CONED  795116007500005  2015
# 20460 2017-01-11 12:54:48.692538  PJM   CONED  795116007500005  2016
# 20461 2017-01-11 12:54:48.692538  PJM   CONED  797501015500006  2017
# 20462 2017-01-11 12:54:48.692538  PJM   CONED  797504025800002  2015
# 20463 2017-01-11 12:54:48.692538  PJM   CONED  797504025800002  2016
# 20464 2017-01-11 12:54:48.692538  PJM   CONED  797504025800002  2017
#
#       RateClass Strata MeterType        ICap  CapacityTagValue    HistVar  \
# 0             9      9      None   86.849577               NaN        NaN
# 1             9      9      None   67.566771           75.2000  10.150570
# 2             9      9      None   82.011537          101.0000  18.800458
# 3             9      9      None   76.797542               NaN        NaN
# 4             9      9      None    3.117239            3.3100   5.823586
# 5             9      9      None    3.914402            3.9231   0.221717
# 6             9      9      None    3.761557               NaN        NaN
# 7             9      9      None   22.489403           24.3600   7.678968
# 8             9      9      None   16.346038           12.2915  32.986517
# 9             9      9      None   12.246620               NaN        NaN
# 10            9      9      None    7.598271            8.0600   5.728650
# 11            9      9      None    6.165183            6.6660   7.513008
# 12            9      9      None    4.929820               NaN        NaN
# 13            9      9      None    3.714072            3.7219   0.210332
# 14            9      9      None   10.521143               NaN        NaN
# 15            1      1      None    0.102972            0.1405  26.710276
# 16            1      1      None    0.184819               NaN        NaN
# 17            2      2      None    0.035459               NaN        NaN
# 18            1      1      None    0.186616               NaN        NaN
# 19            2      2      None    8.972372               NaN        NaN
# 20            1      1      None    1.011067            1.0900   7.241532
# 21            1      1      None    1.397362            1.5304   8.692989
# 22            1      1      None    1.422504               NaN        NaN
# 23            1      1      None    1.818961            1.7000   6.997697
# 24            1      1      None    2.526713            2.7673   8.693936
# 25            1      1      None    2.693887               NaN        NaN
# 26            7      7      None    1.188877            7.1000  83.255258
# 27            7      7      None    0.824613            0.8981   8.182521
# 28            7      7      None    0.800963               NaN        NaN
# 29            9      9      None   74.188764           82.6300  10.215704
# ...         ...    ...       ...         ...               ...        ...
# 20435         9      9      None   12.631977               NaN        NaN
# 20436         2      2      None    0.775413            0.3900  98.823882
# 20437         2      2      None    0.924269            1.0178   9.189561
# 20438         2      2      None    0.667376               NaN        NaN
# 20439         2      2      None    0.635209            0.3900  62.874176
# 20440         2      2      None    0.626972            0.6904   9.187131
# 20441         2      2      None    0.436019               NaN        NaN
# 20442         2      2      None    1.741444            3.2200  45.917882
# 20443         2      2      None    1.733922            1.9390  10.576485
# 20444         2      2      None    1.912023               NaN        NaN
# 20445         9      9      None   16.235034           16.2300   0.031018
# 20446         9      9      None   15.035421           15.0354   0.000141
# 20447         9      9      None   14.462699               NaN        NaN
# 20448         2      2      None    0.758245            0.3900  94.421877
# 20449         2      2      None    0.930156            1.0243   9.191085
# 20450         2      2      None    0.569494               NaN        NaN
# 20451         2      2      None    0.678129            0.3900  73.879188
# 20452         2      2      None    0.691730            0.7618   9.197989
# 20453         2      2      None    0.395976               NaN        NaN
# 20454         9      9      None    5.105421            5.4200   5.804032
# 20455         9      9      None    7.184872            7.2529   0.937940
# 20456         9      9      None    6.288753               NaN        NaN
# 20457         9      9      None   32.582569           34.6900   6.075040
# 20458         9      9      None   34.822997           43.5506  20.040144
# 20459         9      9      None    3.724319            3.8500   3.264430
# 20460         9      9      None    5.687186            5.6872   0.000241
# 20461         9      9      None  100.411773               NaN        NaN
# 20462        51     51      None    3.926156           40.5300  90.312962
# 20463        51     51      None    5.481231            4.2750  28.215938
# 20464        51     51      None    5.770052               NaN        NaN
#
#       Valid
# 0      NULL
# 1         0
# 2         0
# 3      NULL
# 4         0
# 5         1
# 6      NULL
# 7         0
# 8         0
# 9      NULL
# 10        0
# 11        0
# 12     NULL
# 13        1
# 14     NULL
# 15        0
# 16     NULL
# 17     NULL
# 18     NULL
# 19     NULL
# 20        0
# 21        0
# 22     NULL
# 23        0
# 24        0
# 25     NULL
# 26        0
# 27        0
# 28     NULL
# 29        0
# ...     ...
# 20435  NULL
# 20436     0
# 20437     0
# 20438  NULL
# 20439     0
# 20440     0
# 20441  NULL
# 20442     0
# 20443     0
# 20444  NULL
# 20445     1
# 20446     1
# 20447  NULL
# 20448     0
# 20449     0
# 20450  NULL
# 20451     0
# 20452     0
# 20453  NULL
# 20454     0
# 20455     1
# 20456  NULL
# 20457     0
# 20458     0
# 20459     0
# 20460     1
# 20461  NULL
# 20462     0
# 20463     0
# 20464  NULL
#
# [20465 rows x 12 columns]

# %%
# aggregate and count
details = results.groupby(['MeterType', 'Year', 'RateClass',
                           'Strata', 'Valid']
                          )[['ICap', 'CapacityTagValue']].count()

# %%
details
# Out:
# Empty DataFrame
# Columns: [ICap, CapacityTagValue]
# Index: []

# %%
comp = r.compare_.copy()
null_idx = comp[pd.isnull(comp['HistVar'])].index
valid_idx = comp[comp['HistVar'] <= 2.0].index
invalid_idx = comp[comp['HistVar'] > 2.0].index

# %%
comp.ix[valid_idx].shape
# Out:
# (1856, 11)

# %%
comp.ix[invalid_idx].shape
# Out:
# (11057, 11)

# %%
r.analyze_comparison()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-21bd3f6a3ace> in <module>()
# ----> 1 r.analyze_comparison()
#
# /home/miles/Projects/BusinessLab/JustEnergy/icap/results/results.py in analyze_comparison(self, write_to_excel)
#      64         null_idx = results[pd.isnull(results['HistVar'])].index
#      65         valid_idx = results[results['HistVar'] <= 2.0].index
# ---> 66         invalid_idx = results[results['HistVar'] > 2.0].index
#      67
#      68         # assign values to outcomes on their index
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# /home/miles/anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     737         result = lib.vec_compare(x, y, op)
#     738     else:
# --> 739         result = lib.scalar_compare(x, y, op)
#     740     return result
#     741
#
# pandas/lib.pyx in pandas.lib.scalar_compare (pandas/lib.c:14839)()
#
# TypeError: unorderable types: str() <= float()

# %%
def is_tod(rate_class):
    """Returns proper REGEX based on rate class. Meters can be either
    TIME OF DAY (if TODQ == 1 then 'Ta
') or 
    NOT TIME OF DAY (if TODQ == 0 then '[^T]')
    
    if c.rc_map.ix[rate_class]['TODQ']:
        return 'T'
    return '[^T]'
    """
    if meter_logic == 'VTOU':
        return 'T'
    return '[^T]'

# %%
# Query the Load Shape Adjustment Table
lst_qry = "select * from CONED_LoadShapeTempAdj where Strata != ''"
lst = pd.read_sql(lst_qry, conn)

## OPTIMIZING THE LOAD PROFILE PROCESS
# 1) Merge the  Load Shape Adjustment Table with Temperature Variants on
#    the DAY[TYPE, OfWeek] columns. 
# 2) Then filter the table where [TEMP L BOUND] <= Max <= [TEMP U Bound]
tmp = pd.merge(lst, c.temp_var.reset_index(), left_on='DAYTYPE', right_on='DayOfWeek')
tmp = tmp[(tmp['TEMP L BOUND'] <= tmp['Max']) & (tmp['Max'] <= tmp['TEMP U BOUND'])]

# %%
tmp.sort_values(by=['ObservedDate'])
tmp2 = tmp.set_index('ObservedDate')

# %%
from datetime import datetime
from itertools import islice

"""When BilledDemand == 0, the MCD calculation chooses the zero value instead of
NormalizedUsage. Any location where a zero occurs is replaced with np.inf. This
ensures that when BilledDemand has a zero value, the NormalizedValue is selected
"""
c.monthly.replace(to_replace=0, value=np.inf, inplace=True)
c.monthly.head()

# %%
"""
Metered Coincident Demand (MCD)

MCD is computed differently for all three meter types. 
    METERTYPE:
        CON: MCD = Normalized Usage
        DMD: MCD = min(normalized usage, billed demand)
        INT: if variance < 4% then MCD = Usage on CPDayHour
             else MCD = min(normalized usage, billed demand)
"""
from datetime import datetime
from itertools import islice
error_counts = 0
rec_count = 0
start_time = datetime.now()


for rec in c.monthly.itertuples():
    
    # Parse the record index
    prem, year = rec[0]
    
    # Parse record
    rate_class, strata, zone, stratum, tod, \
    bill_start, bill_end, usage, demand, \
    meter_type, mcd, normalized_usage, \
    meter_logic, meter_regex = rec[1:]
    
    rate_class = int(rate_class)
   
    # Service class mapping
    service_class = c.rc_map.ix[rate_class]['Map']    
    
    # Slice billcycle from temperature variants
    billcycle = c.temp_var.ix[bill_start:bill_end]
    
    # Join bill cycle with modified LoadShapeAdjustmentTable (LST)
    local_lst = pd.merge(billcycle, c.lst, 
                        left_index=True, right_index=True, # index = ObservedDate
                        on=['Max', 'DayOfWeek'])

    # Filter for Straum condition
    local_lst = local_lst[(local_lst['STRAT L BOUND'] <= float(stratum)) & 
                          (float(stratum) <= local_lst['STRAT U BOUND'])]
    
   
    # Filter for TimeOfDay meter type and Service Class Mapping
    tod_mask = local_lst['STRATA'].str.contains(meter_regex)
    sc_mask = (local_lst['SC'] == c.rc_map.ix[rate_class]['Map'])
    mask = (tod_mask == 1) & (sc_mask == 1)
    local_lst = local_lst.ix[mask]
    
    # Check to ensure proper filtering has occurred
    if local_lst.shape[0] != billcycle.shape[0]:
        error_counts += 1
        continue
    
    # Extract the kiloWatt hour columns
    kw_cols = [col for col in local_lst.columns if 'KW' in col]
    local_lst = local_lst[kw_cols]
    
    # Convert coincident peak information into usable keys
    # Compute the Customer Scaling Factor
    # Extract the Load Profile from the billing cycle
    # Compute the normalized usage
    cp_day, hr = c.cp.ix[str(year)]
    csf = usage / local_lst.values.sum()
    load_profile = local_lst.ix[cp_day]['KW' + str(hr)]
    normalized_usage = load_profile * csf
  
    
    ## MCD ##
    # if 'DMD' then MCD = min(normalized_usage, billed_demand)
    # if 'CON' then MCD = normalized_usage
    if meter_type == 'DMD':
        mcd = np.minimum(normalized_usage, demand)
    else:
        mcd = normalized_usage
        
    # Update the monthly usage values
    c.monthly.loc[(prem, year), ['NormUsage', 'MCD']
                 ] = [normalized_usage, mcd]

    
    
    rec_count += 1
    if rec_count % 1000 == 0:
        print('Current: %d Percent: %.4f Errors: %d' %(
                rec_count, rec_count / c.monthly.shape[0], error_counts))


## Timing
elapsed_time = datetime.now() - start_time

print('Total Time: %s' % elapsed_time)
print('Average Time: %f' % (elapsed_time.total_seconds() / rec_count) )

# %%
c.monthly

# %%
tmp = pd.merge(c.monthly.reset_index(), c.util,
        how='left',
        left_on=['Year', 'ZoneCode'],
        right_on=['Year', 'Zone'])

# %%
# %%time 

tmp['Factor'] = tmp['Factor'].apply(lambda x: 1.0 + x)

match_mask = tmp['MeterType_x'] == tmp['MeterType_y']
all_mask = tmp['MeterType_y'] == 'ALL'
mask = (match_mask == 1) | (all_mask == 1)

def coned_icap(g):
    #if g['ParameterId'].shape[0] != 2: # Subzone and Forecast Trueup Factors
    #    return np.nan
    #normalized_usage = g['MCD'].ix[0]
    mcd = g['MCD'].values[0]
    stf = g[g['ParameterId'] == 'SubzoneTrueupFactor']['Factor'].values[0]
    ftf = g[g['ParameterId'] == 'ForecastTrueupFactor']['Factor'].values[0]
    icap = mcd * stf * ftf

    return mcd * stf * ftf

# %%
icap = tmp.ix[mask].groupby(by=['PremiseId', 'Year', 'RateClass', 'MeterType_x', 'MeterLogic']
                    ).apply(coned_icap).reset_index()

# %%
icap[icap['PremiseId'] == '494141010200009']

# %%
icap[icap['PremiseId'] == '700536121000000']

# %%
historic = pd.read_sql("select * from CapacityTagHistorical where UtilityId = 'CONED'", conn)

# %%
icap['Year'] = icap['Year'].apply(lambda x: x + 1)

# %%
tmp = pd.merge(icap, historic, 
         left_on=['PremiseId', 'Year'],
        right_on=['PremiseID', 'CPYearID'])
tmp.rename(columns={0:'ICap'}, inplace=True)

tmp['Variance'] = (tmp['CapacityTagValue'] - tmp['ICap']) / tmp['CapacityTagValue'] * 100.

# %%
tmp['Valid'] = 0
valid_idx = tmp[tmp['Variance'] <= 2.0].index
tmp.set_value(valid_idx, 'Valid', 1)

tmp.groupby(['MeterType_x', 'Year', 'RateClass', 'Valid']
           )[['ICap', 'CapacityTagValue']].count()
